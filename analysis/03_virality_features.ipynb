# %% [markdown]
# # Virality Feature Engineering
#
# **Goal:** identify what predicts high view/engagement for scam-bait content. Output feeds the Social Agent.
#
# Candidate features:
# - Call duration vs. views correlation
# - Scam type (IRS, tech support, etc.) — which drives most shares?
# - Upload day/time — when does scam-bait content perform best?
# - Thumbnail type (face vs. graphic vs. text)
# - Title sentiment / keyword presence
# - Frustration clip length (seconds of scammer losing it)
#
# Output:
# - Ranked feature importances
# - Best posting time model → used by `backend/app/agents/social.py`

# %%
# TODO: implement after notebook 02 has data
