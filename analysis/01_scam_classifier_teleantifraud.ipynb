# %% [markdown]
# # Scam Classifier — TeleAntiFraud-28k
#
# **Goal:** train / evaluate the Classifier Agent using the TeleAntiFraud-28k dataset (arXiv 2503.24115).
#
# Steps:
# 1. Download dataset
# 2. EDA — class distribution, transcript length, scam type breakdown
# 3. Baseline: keyword rule-based classifier
# 4. LLM zero-shot classifier (Claude) — baseline
# 5. Fine-tuned embedding classifier (optional)
# 6. Export best model for `backend/app/agents/classifier.py`
#
# Data goes in `analysis/data/` (gitignored).

# %%
# TODO: implement
