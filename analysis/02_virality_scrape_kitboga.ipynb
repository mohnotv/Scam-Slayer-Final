# %% [markdown]
# # Virality Scrape — Kitboga / Pleasant Green / Scammer Payback
#
# **Goal:** scrape YouTube metadata for scam-bait channels to build a virality features dataset.
#
# Steps:
# 1. YouTube Data API v3 — pull video metadata (views, likes, comments, duration, upload date)
# 2. yt-dlp — optionally download thumbnails and first-10s audio snippets for feature extraction
# 3. Store raw data in `analysis/data/virality_raw.csv` (gitignored)
# 4. Clean + deduplicate
# 5. Hand off to notebook 03 for feature engineering
#
# Channels: UCdbFbP0dBKMHPmMWhLKQKKw (Kitboga), UC7tscMzIUEnalCZ6OZGiapw (Scammer Payback)

# %%
# TODO: implement
